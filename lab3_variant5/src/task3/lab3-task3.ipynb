# %% [markdown]
# # Лабораторная работа №3. Задание 3
# ## Обработка строк с применением потокового редактора sed
#
# **Студент:** Давидович Александр Николаевич
# **Группа:** 12ТП
# **Вариант:** 5

# %% [markdown]
# ## Используемые утилиты
#
# - **sed:** GNU sed 4.8+
# - **Python:** 3.12

# %% [markdown]
# ## Примеры работы с sed

# %%
# !cat ../../data/books

# %%
# !sed -n '/book/ p' ../../data/books

# %%
# !sed -n '2,5 p' ../../data/books

# %%
# !sed 's/Яшин/Кашин/' ../../data/list_students.txt

# %% [markdown]
# ## Выводы
#
# sed успешно применен для обработки текста.
