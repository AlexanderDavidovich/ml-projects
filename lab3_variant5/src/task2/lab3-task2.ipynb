# %% [markdown]
# # Лабораторная работа №3. Задание 2
# ## Основы языка AWK
#
# **Студент:** Давидович Александр Николаевич
# **Группа:** 12ТП

# %% [markdown]
# ## Примеры AWK

# %%
# !awk '{print $1}' ../../data/myfile

# %%
# !awk '($5==4)' ../../data/list_students.txt

# %%
# !awk '($3=="ЭКТ")&&($4==1)' ../../data/list_students.txt

# %%
# !awk '(length($2)>5) {print}' ../../data/list_students.txt

# %%
# !awk '{print NR, $0}' ../../data/list_students.txt

# %%
# !awk -F',' '$3>6 {print $1, $2}' ../../data/colours.csv

# %% [markdown]
# ## Выводы
#
# Все примеры AWK выполнены.
